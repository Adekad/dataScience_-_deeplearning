# %% [markdown]
# ### Les séries temporelles

# %%
# Une série temporelle est une série dont l'index est le temps

import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
energy = pd.read_csv("https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv")

# %%
energy
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2006-01-01   1069.18400      NaN     NaN         NaN
# 1     2006-01-02   1380.52100      NaN     NaN         NaN
# 2     2006-01-03   1442.53300      NaN     NaN         NaN
# 3     2006-01-04   1457.21700      NaN     NaN         NaN
# 4     2006-01-05   1477.13100      NaN     NaN         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   object
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 171.3+ KB

# %%
energy.describe()
# Out:
#        Consumption         Wind        Solar   Wind+Solar
# count  4383.000000  2920.000000  2188.000000  2187.000000
# mean   1338.675836   164.814173    89.258695   272.663481
# std     165.775710   143.692732    58.550099   146.319884
# min     842.395000     5.757000     1.968000    21.478000
# 25%    1217.859000    62.353250    35.179250   172.185500
# 50%    1367.123000   119.098000    86.407000   240.991000
# 75%    1457.761000   217.900250   135.071500   338.988000
# max    1709.568000   826.278000   241.580000   851.556000

# %%
energy['Wind'].isna().any() # any() qui renvoie true si y a une valeur manquante
# Out:
# True

# %%
energy['Date'] = pd.to_datetime(energy['Date'])

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   datetime64[ns]
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 171.3 KB

# %%
energy = energy.set_index('Date')
energy
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN
# 2006-01-02   1380.52100      NaN     NaN         NaN
# 2006-01-03   1442.53300      NaN     NaN         NaN
# 2006-01-04   1457.21700      NaN     NaN         NaN
# 2006-01-05   1477.13100      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 4 columns]

# %%
energy.isnull().any()
# Out:
# Consumption    False
# Wind            True
# Solar           True
# Wind+Solar      True
# dtype: bool

# %%
energy.isnull().mean() * 100   # La proportion de valeur manquante par colonne
# Out:
# Consumption     0.000000
# Wind           33.378964
# Solar          50.079854
# Wind+Solar     50.102669
# dtype: float64

# %%
energy.index[:5]
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
energy.index[:5].year # month, day, day_name()
# Out:
# Int64Index([2006, 2006, 2006, 2006, 2006], dtype='int64', name='Date')

# %%
energy['year'] = energy.index.year

# %%
energy['month'] = energy.index.month

# %%
energy['day_name'] = energy.index.day_name()
energy
# Out:
#             Consumption     Wind   Solar  Wind+Solar  year  month   day_name
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN  2006      1     Sunday
# 2006-01-02   1380.52100      NaN     NaN         NaN  2006      1     Monday
# 2006-01-03   1442.53300      NaN     NaN         NaN  2006      1    Tuesday
# 2006-01-04   1457.21700      NaN     NaN         NaN  2006      1  Wednesday
# 2006-01-05   1477.13100      NaN     NaN         NaN  2006      1   Thursday
# ...                 ...      ...     ...         ...   ...    ...        ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017     12  Wednesday
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017     12   Thursday
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017     12     Friday
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017     12   Saturday
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017     12     Sunday
#
# [4383 rows x 7 columns]

# %%
#energy['weekend'] = ((energy['day_name'] == 'Sunday') | (energy['day_name'] == 'Saturday')) la parenthèse est importante
energy['weekend'] = energy['day_name'].isin(['Sunday', 'Saturday'])
energy
# Out:
#             Consumption     Wind   Solar  Wind+Solar  year  month   day_name  \
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN  2006      1     Sunday
# 2006-01-02   1380.52100      NaN     NaN         NaN  2006      1     Monday
# 2006-01-03   1442.53300      NaN     NaN         NaN  2006      1    Tuesday
# 2006-01-04   1457.21700      NaN     NaN         NaN  2006      1  Wednesday
# 2006-01-05   1477.13100      NaN     NaN         NaN  2006      1   Thursday
# ...                 ...      ...     ...         ...   ...    ...        ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017     12  Wednesday
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017     12   Thursday
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017     12     Friday
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017     12   Saturday
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017     12     Sunday
#
#             weekend
# Date
# 2006-01-01     True
# 2006-01-02    False
# 2006-01-03    False
# 2006-01-04    False
# 2006-01-05    False
# ...             ...
# 2017-12-27    False
# 2017-12-28    False
# 2017-12-29    False
# 2017-12-30     True
# 2017-12-31     True
#
# [4383 rows x 8 columns]

# %%
energy['year'].max()
# Out:
# 2017

# %%
energy.loc["2010-05":"2013-08"]
# Out:
#             Consumption     Wind    Solar  Wind+Solar  year  month   day_name  \
# Date
# 2010-05-01     1003.133   71.799      NaN         NaN  2010      5   Saturday
# 2010-05-02     1025.534   38.272      NaN         NaN  2010      5     Sunday
# 2010-05-03     1357.760   42.253      NaN         NaN  2010      5     Monday
# 2010-05-04     1380.307   97.348      NaN         NaN  2010      5    Tuesday
# 2010-05-05     1377.111   94.939      NaN         NaN  2010      5  Wednesday
# ...                 ...      ...      ...         ...   ...    ...        ...
# 2013-08-27     1306.896   60.838   95.038     155.876  2013      8    Tuesday
# 2013-08-28     1295.979   21.264  112.823     134.087  2013      8  Wednesday
# 2013-08-29     1285.918   11.641  148.324     159.965  2013      8   Thursday
# 2013-08-30     1267.145   35.407  145.143     180.550  2013      8     Friday
# 2013-08-31     1072.235  125.602  105.095     230.697  2013      8   Saturday
#
#             weekend
# Date
# 2010-05-01     True
# 2010-05-02     True
# 2010-05-03    False
# 2010-05-04    False
# 2010-05-05    False
# ...             ...
# 2013-08-27    False
# 2013-08-28    False
# 2013-08-29    False
# 2013-08-30    False
# 2013-08-31     True
#
# [1219 rows x 8 columns]

# %%
sns.set_style("whitegrid")
energy["Consumption"].plot(figsize=(10, 8)) # linewhidth=.5 ne marche pas
plt.show()

# %%
# energy.groupby("day_name").groups
energy.groupby("day_name").sum()
# Out:
#             Consumption       Wind      Solar  Wind+Solar     year  month  \
# day_name
# Friday     873034.67157  67195.390  28035.810   83131.425  1259202   4081
# Monday     870006.24492  67131.668  28211.238   85333.933  1259195   4082
# Saturday   751544.19949  70724.544  27360.623   85230.882  1259203   4089
# Sunday     691646.51735  71909.961  27662.976   88529.003  1261211   4087
# Thursday   889645.06681  68903.054  28529.677   85806.246  1259200   4084
# Tuesday    894101.79246  66726.847  27558.333   82926.441  1259197   4079
# Wednesday  897437.69479  68665.920  27939.367   85357.104  1259198   4088
#
#            weekend
# day_name
# Friday           0
# Monday           0
# Saturday       626
# Sunday         627
# Thursday         0
# Tuesday          0
# Wednesday        0

# %%
energy.groupby("day_name").sum()["Consumption"].sort_values()
# Out:
# day_name
# Sunday       691646.51735
# Saturday     751544.19949
# Monday       870006.24492
# Friday       873034.67157
# Thursday     889645.06681
# Tuesday      894101.79246
# Wednesday    897437.69479
# Name: Consumption, dtype: float64

# %%
energy.groupby("day_name").sum()["Consumption"].sort_values()
# Out:
# day_name
# Sunday       691646.51735
# Saturday     751544.19949
# Monday       870006.24492
# Friday       873034.67157
# Thursday     889645.06681
# Tuesday      894101.79246
# Wednesday    897437.69479
# Name: Consumption, dtype: float64

# %%
groupDay = energy.groupby("day_name").sum()["Consumption"].reset_index()
groupDay
# Out:
#     day_name   Consumption
# 0     Friday  873034.67157
# 1     Monday  870006.24492
# 2   Saturday  751544.19949
# 3     Sunday  691646.51735
# 4   Thursday  889645.06681
# 5    Tuesday  894101.79246
# 6  Wednesday  897437.69479

# %%
order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
sns.barplot(x = groupDay["day_name"], y = groupDay["Consumption"], order=order)
plt.show()

# %% [markdown]
# #### Visualisation par année

# %%
grid = sns.FacetGrid(energy, row="year")
grid.map(plt.plot, "Consumption")

# %%
data = energy.loc["2016"].copy()
data
# Out:
#             Consumption     Wind   Solar  Wind+Solar  year  month   day_name  \
# Date
# 2016-01-01     1060.366  107.209  18.563     125.772  2016      1     Friday
# 2016-01-02     1192.698  409.622   9.406     419.028  2016      1   Saturday
# 2016-01-03     1179.282  406.296  13.519     419.815  2016      1     Sunday
# 2016-01-04     1456.294  278.460  10.080     288.540  2016      1     Monday
# 2016-01-05     1506.737  206.468  12.549     219.017  2016      1    Tuesday
# ...                 ...      ...     ...         ...   ...    ...        ...
# 2016-12-27     1289.324  640.895  23.448     664.343  2016     12    Tuesday
# 2016-12-28     1294.881  214.990  19.450     234.440  2016     12  Wednesday
# 2016-12-29     1295.897  167.698  42.910     210.608  2016     12   Thursday
# 2016-12-30     1291.044  239.257  48.546     287.803  2016     12     Friday
# 2016-12-31     1212.568  315.063  34.580     349.643  2016     12   Saturday
#
#             weekend
# Date
# 2016-01-01    False
# 2016-01-02     True
# 2016-01-03     True
# 2016-01-04    False
# 2016-01-05    False
# ...             ...
# 2016-12-27    False
# 2016-12-28    False
# 2016-12-29    False
# 2016-12-30    False
# 2016-12-31     True
#
# [366 rows x 8 columns]

# %%
sns.scatterplot( x = data.index, y=data["Consumption"])
plt.xlim(data.index.min(), data.index.max())
# Out:
# (16801.0, 17166.0)

# %%
# La suite des graphe à Ctrl CV sur son github

# %% [markdown]
# #### Resampling (pourvoir grouper les données par semaine, mois, trimestre etc...)

# %%
# Consormation par semaine
energy.drop(["year", "month", "weekend", "day_name"], axis=1).resample("W").mean()
# Out:
#             Consumption        Wind      Solar  Wind+Solar
# Date
# 2006-01-01  1069.184000         NaN        NaN         NaN
# 2006-01-08  1381.300143         NaN        NaN         NaN
# 2006-01-15  1486.730286         NaN        NaN         NaN
# 2006-01-22  1490.031143         NaN        NaN         NaN
# 2006-01-29  1514.176857         NaN        NaN         NaN
# ...                 ...         ...        ...         ...
# 2017-12-03  1536.236314  284.334286  18.320857  302.655143
# 2017-12-10  1554.824946  636.514714  16.440286  652.955000
# 2017-12-17  1543.856889  442.531857  18.143714  460.675571
# 2017-12-24  1440.342401  339.018429   9.895143  348.913571
# 2017-12-31  1203.265211  604.699143  19.240143  623.939286
#
# [627 rows x 4 columns]

# %%
# Consormation par mois
energy.drop(["year", "month", "weekend", "day_name"], axis=1).resample("M").mean()
# Out:
#             Consumption        Wind       Solar  Wind+Solar
# Date
# 2006-01-31  1461.442065         NaN         NaN         NaN
# 2006-02-28  1467.106893         NaN         NaN         NaN
# 2006-03-31  1418.649161         NaN         NaN         NaN
# 2006-04-30  1275.058900         NaN         NaN         NaN
# 2006-05-31  1253.488484         NaN         NaN         NaN
# ...                 ...         ...         ...         ...
# 2017-08-31  1291.283022  177.412839  148.477677  325.890516
# 2017-09-30  1335.952031  209.591000  102.643033  312.234033
# 2017-10-31  1366.297385  402.583774   68.727645  471.311419
# 2017-11-30  1477.990818  341.966700   27.701467  369.668167
# 2017-12-31  1435.842075  475.014065   15.941000  490.955065
#
# [144 rows x 4 columns]

# %%
# Consormation par trimestre
energy.drop(["year", "month", "weekend", "day_name"], axis=1).resample("Q").mean()
# Out:
#             Consumption        Wind       Solar  Wind+Solar
# Date
# 2006-03-31  1448.464678         NaN         NaN         NaN
# 2006-06-30  1256.740220         NaN         NaN         NaN
# 2006-09-30  1268.088424         NaN         NaN         NaN
# 2006-12-31  1387.817609         NaN         NaN         NaN
# 2007-03-31  1434.139633         NaN         NaN         NaN
# 2007-06-30  1278.652451         NaN         NaN         NaN
# 2007-09-30  1304.044261         NaN         NaN         NaN
# 2007-12-31  1426.411250         NaN         NaN         NaN
# 2008-03-31  1445.339879         NaN         NaN         NaN
# 2008-06-30  1305.837703         NaN         NaN         NaN
# 2008-09-30  1296.808130         NaN         NaN         NaN
# 2008-12-31  1368.558348         NaN         NaN         NaN
# 2009-03-31  1353.290700         NaN         NaN         NaN
# 2009-06-30  1156.934824         NaN         NaN         NaN
# 2009-09-30  1189.751359         NaN         NaN         NaN
# 2009-12-31  1339.163815         NaN         NaN         NaN
# 2010-03-31  1409.179389  120.480933         NaN         NaN
# 2010-06-30  1250.463088   78.494473         NaN         NaN
# 2010-09-30  1277.265207   74.107500         NaN         NaN
# 2010-12-31  1418.065380  120.734848         NaN         NaN
# 2011-03-31  1405.507067  125.518278         NaN         NaN
# 2011-06-30  1289.128088   98.782429         NaN         NaN
# 2011-09-30  1259.112739  100.250902         NaN         NaN
# 2011-12-31  1360.537196  159.604637         NaN         NaN
# 2012-03-31  1356.101044  171.930802   43.201703  215.132505
# 2012-06-30  1242.014615  100.793176  114.815396  215.608571
# 2012-09-30  1224.858130   85.089761  113.929924  199.019685
# 2012-12-31  1309.340011  143.657902   32.893728  176.551630
# 2013-03-31  1317.814556  143.229356   35.921852  181.722682
# 2013-06-30  1211.940473  105.398033  120.976758  226.374791
# 2013-09-30  1228.943011   81.170043  129.581641  210.751685
# 2013-12-31  1319.393511  187.481793   37.698489  225.180283
# 2014-03-31  1464.359389  190.018764   60.994841  253.376310
# 2014-06-30  1331.275385  106.917901  138.597011  245.514912
# 2014-09-30  1323.279239   88.282000  121.705815  209.987815
# 2014-12-31  1407.442674  177.657924   36.103239  213.761163
# 2015-03-31  1480.596578  240.033711   53.522333  293.556044
# 2015-06-30  1318.366890  157.808000  147.251132  305.059132
# 2015-09-30  1332.259391  166.170750  138.659641  304.830391
# 2015-12-31  1407.300217  284.975250   42.756391  327.731641
# 2016-03-31  1458.561901  275.923725   47.534714  323.458440
# 2016-06-30  1332.364978  168.890736  145.441462  314.332198
# 2016-09-30  1310.366891  148.002609  146.859424  294.862033
# 2016-12-31  1428.252761  249.062717   37.944837  287.007554
# 2017-03-31  1483.426144  300.164289   61.268178  361.432467
# 2017-06-30  1318.747868  229.747176  157.629418  387.376593
# 2017-09-30  1304.520789  187.837522  136.613674  324.451196
# 2017-12-31  1426.152693  407.223196   37.562739  444.785935

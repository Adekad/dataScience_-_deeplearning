# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data_url = "./data/data-analyst/datasets/SalesAnalysis/Sales_Data/"
os.listdir(data_url)
# Out:
# ['Sales_July_2019.csv',
#  'Sales_April_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_August_2019.csv']

# %%
vente_janv = pd.read_csv(data_url + "Sales_January_2019.csv")
vente_janv
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
vente_janv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9723 entries, 0 to 9722
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          9697 non-null   object
#  1   Product           9697 non-null   object
#  2   Quantity Ordered  9697 non-null   object
#  3   Price Each        9697 non-null   object
#  4   Order Date        9697 non-null   object
#  5   Purchase Address  9697 non-null   object
# dtypes: object(6)
# memory usage: 455.9+ KB

# %%
vente_janv.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count       9697                  9697             9697       9697
# unique      9269                    20                8         19
# top     Order ID  USB-C Charging Cable                1      11.95
# freq          16                  1171             8795       1171
#
#         Order Date  Purchase Address
# count         9697              9697
# unique        8077              9161
# top     Order Date  Purchase Address
# freq            16                16

# %%
files = [fichier for fichier in os.listdir(data_url) if fichier.endswith('.csv')]
files
# Out:
# ['Sales_July_2019.csv',
#  'Sales_April_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_August_2019.csv']

# %%
df = pd.DataFrame()

for file in files:
    data_inter = pd.read_csv(data_url + file)
    df = pd.concat([df, data_inter])

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       222910    Apple Airpods Headphones                1        150
# 1       222911               Flatscreen TV                1        300
# 2       222912       AA Batteries (4-pack)                1       3.84
# 3       222913       AA Batteries (4-pack)                1       3.84
# 4       222914      AAA Batteries (4-pack)                5       2.99
# ...        ...                         ...              ...        ...
# 12006   248146  Bose SoundSport Headphones                1      99.99
# 12007   248147      AAA Batteries (4-pack)                3       2.99
# 12008   248148       AA Batteries (4-pack)                1       3.84
# 12009   248149        USB-C Charging Cable                1      11.95
# 12010   248150       AA Batteries (4-pack)                1       3.84
#
#            Order Date                         Purchase Address
# ...

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186850 entries, 0 to 12010
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 10.0+ MB

# %%
df.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %%
# df.isnull() ne marche pas comme je le veux
df.isnull().sum(axis=0)  # axis = 0était pas vraiment utile
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
val_manq = df[df.isnull().any(axis=1)]  #  avy pour sélectionner toutes les lignes isnull
val_manq
# Out:
#       Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 199        NaN     NaN              NaN        NaN        NaN              NaN
# 315        NaN     NaN              NaN        NaN        NaN              NaN
# 599        NaN     NaN              NaN        NaN        NaN              NaN
# 675        NaN     NaN              NaN        NaN        NaN              NaN
# 1027       NaN     NaN              NaN        NaN        NaN              NaN
# ...        ...     ...              ...        ...        ...              ...
# 9749       NaN     NaN              NaN        NaN        NaN              NaN
# 10496      NaN     NaN              NaN        NaN        NaN              NaN
# 10714      NaN     NaN              NaN        NaN        NaN              NaN
# 10864      NaN     NaN              NaN        NaN        NaN              NaN
# 10874      NaN     NaN              NaN        NaN        NaN              NaN
#
# [545 rows x 6 columns]

# %%
val_manq.isnull().all()  #  Pour vérifier que toutes les valeurs sont vraiment manquantes dans toutes les colonnes
# Out:
# Order ID            True
# Product             True
# Quantity Ordered    True
# Price Each          True
# Order Date          True
# Purchase Address    True
# dtype: bool

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (186305, 6)

# %%
df.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %%
df[df['Order ID'] == 'Order ID']
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 775    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1391   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1438   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1624   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1720   Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...         ...      ...               ...         ...         ...
# 9605   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 10217  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 10338  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 10705  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11004  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#        Purchase Address
# 775    Purchase Address
# 1391   Purchase Address
# 1438   Purchase Address
# 1624   Purchase Address
# 1720   Purchase Address
# ...

# %%
"1584".isdigit()
# Out:
# True

# %%
df.loc[~df['Order ID'].str.isdigit(), :]  #  Afficher toutes les lignes ou on n'a pas de digit
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 775    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1391   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1438   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1624   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1720   Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...         ...      ...               ...         ...         ...
# 9605   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 10217  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 10338  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 10705  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11004  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#        Purchase Address
# 775    Purchase Address
# 1391   Purchase Address
# 1438   Purchase Address
# 1624   Purchase Address
# 1720   Purchase Address
# ...

# %%
df_clean = df.drop(df.loc[~df['Order ID'].str.isdigit(), :].index)  # Supp les ID manquants

# %%
df_clean.loc[~df['Order ID'].str.isdigit(), :]  #  Afficher toutes les lignes ou on n'a pas de digit
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address]
# Index: []

# %%
df_clean
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       222910    Apple Airpods Headphones                1        150
# 1       222911               Flatscreen TV                1        300
# 2       222912       AA Batteries (4-pack)                1       3.84
# 3       222913       AA Batteries (4-pack)                1       3.84
# 4       222914      AAA Batteries (4-pack)                5       2.99
# ...        ...                         ...              ...        ...
# 12006   248146  Bose SoundSport Headphones                1      99.99
# 12007   248147      AAA Batteries (4-pack)                3       2.99
# 12008   248148       AA Batteries (4-pack)                1       3.84
# 12009   248149        USB-C Charging Cable                1      11.95
# 12010   248150       AA Batteries (4-pack)                1       3.84
#
#            Order Date                         Purchase Address
# ...

# %% [markdown]
# #### Changement des types

# %%
df_clean['Quantity Ordered'] = df_clean['Quantity Ordered'].astype('int')

# %%
df_clean['Order ID'] = df_clean['Order ID'].astype('int')

# %%
df_clean['Price Each'] = pd.to_numeric(df_clean['Price Each'])

# %%
df_clean['Order Date'] = pd.to_datetime(df_clean['Order Date'])

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182735 entries, 0 to 12010
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          182735 non-null  int64
#  1   Product           182735 non-null  object
#  2   Quantity Ordered  182735 non-null  int64
#  3   Price Each        182735 non-null  float64
#  4   Order Date        182735 non-null  datetime64[ns]
#  5   Purchase Address  182735 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 9.8+ MB

# %% [markdown]
# #### Le mois avec le plus grand chiffre d'affaire

# %%
df_clean = df_clean.set_index('Order Date')

# %%
df_clean.sort_index(inplace=True)
df_clean
# Out:
#                      Order ID                     Product  Quantity Ordered  \
# Order Date
# 2019-01-01 03:07:00    147268            Wired Headphones                 1
# 2019-01-01 03:40:00    148041        USB-C Charging Cable                 1
# 2019-01-01 04:56:00    149343    Apple Airpods Headphones                 1
# 2019-01-01 05:53:00    149964      AAA Batteries (4-pack)                 1
# 2019-01-01 06:03:00    149350        USB-C Charging Cable                 2
# ...                       ...                         ...               ...
# 2020-01-01 04:13:00    304165      AAA Batteries (4-pack)                 1
# 2020-01-01 04:21:00    299125        USB-C Charging Cable                 1
# 2020-01-01 04:54:00    305840  Bose SoundSport Headphones                 1
# 2020-01-01 05:13:00    300519  Bose SoundSport Headphones                 1
# 2020-01-01 05:13:00    300519    Lightning Charging Cable                 1
#
# ...

# %%
df_clean['Month'] = df_clean.index.month_name()

# %%
df_clean["Chiffre affaire"] = df_clean['Quantity Ordered'] * df_clean['Price Each']

# %%
df_clean.groupby('Month')['Chiffre affaire'].sum().sort_values(ascending=False)
# Out:
# Month
# December     4557905.42
# October      3679254.16
# April        3336376.42
# November     3149785.09
# May          3101881.04
# March        2755969.40
# July         2587444.91
# June         2524464.99
# August       2191698.31
# February     2158127.48
# September    2050361.26
# January      1786511.29
# Name: Chiffre affaire, dtype: float64

# %%
order = ["January", "February", "March", "April", "May", "June", "July", "August",
         "September", "October", "November", "December"]

# %%
df_clean.groupby('Month')['Chiffre affaire'].sum().loc[order]  # Juste pour ordonner de Janvier à Décembre
# Out:
# Month
# January      1786511.29
# February     2158127.48
# March        2755969.40
# April        3336376.42
# May          3101881.04
# June         2524464.99
# July         2587444.91
# August       2191698.31
# September    2050361.26
# October      3679254.16
# November     3149785.09
# December     4557905.42
# Name: Chiffre affaire, dtype: float64

# %%
df_clean.groupby('Month')['Chiffre affaire'].sum().loc[order].plot.bar(figsize=(10, 8))
plt.title('Chiffres affaire mensuel')
# Out:
# Text(0.5, 1.0, 'Chiffres affaire mensuel')

# %%
df_clean.groupby('Month')['Chiffre affaire'].sum().sort_values(ascending=False).December
# Out:
# 4557905.42

# %% [markdown]
# #### Ville dans laquelle on a le plus vendu de produits

# %%
# On a pas de colonne ville mais on a Adresse

df_clean['Purchase Address'].unique()
# Out:
# array(['9 Lake St, New York City, NY 10001',
#        '760 Church St, San Francisco, CA 94016',
#        '735 5th St, New York City, NY 10001', ...,
#        '731 7th St, New York City, NY 10001',
#        '754 Hickory St, New York City, NY 10001',
#        '657 Spruce St, New York City, NY 10001'], dtype=object)

# %%
def get_ville(adresse): 
    # Fonction pour  récup la ville à partir de l'adresse
    return adresse.split(',')[1].strip()  # split pour une séparation par , 
# et strip pour enlever les espaces(underscod) de par et d'autre

# %%
get_ville('760 Church St, San Francisco, CA 94016')
# Out:
# 'San Francisco'

# %%
# Appliquer la fonction à toute une colonne grâce à apply

df_clean['ville'] = df_clean['Purchase Address'].apply(get_ville)

# %%
df_clean
# Out:
#                      Order ID                     Product  Quantity Ordered  \
# Order Date
# 2019-01-01 03:07:00    147268            Wired Headphones                 1
# 2019-01-01 03:40:00    148041        USB-C Charging Cable                 1
# 2019-01-01 04:56:00    149343    Apple Airpods Headphones                 1
# 2019-01-01 05:53:00    149964      AAA Batteries (4-pack)                 1
# 2019-01-01 06:03:00    149350        USB-C Charging Cable                 2
# ...                       ...                         ...               ...
# 2020-01-01 04:13:00    304165      AAA Batteries (4-pack)                 1
# 2020-01-01 04:21:00    299125        USB-C Charging Cable                 1
# 2020-01-01 04:54:00    305840  Bose SoundSport Headphones                 1
# 2020-01-01 05:13:00    300519  Bose SoundSport Headphones                 1
# 2020-01-01 05:13:00    300519    Lightning Charging Cable                 1
#
# ...

# %%
df_clean['ville'].value_counts()
# Out:
# San Francisco    43948
# Los Angeles      29107
# New York City    24456
# Boston           19575
# Atlanta          14616
# Dallas           14571
# Seattle          14487
# Portland         12261
# Austin            9714
# Name: ville, dtype: int64

# %%
df_clean.groupby('ville')['Quantity Ordered'].sum().plot.bar(figsize=(10, 8))
# Out:
# <AxesSubplot: xlabel='ville'>

# %% [markdown]
# #### Ville dans laquelle on a le plus grand chiffre d'affaire

# %%
df_clean.groupby('ville')['Chiffre affaire'].sum().sort_values(ascending=True).plot.bar(figsize=(10, 8))
# Out:
# <AxesSubplot: xlabel='ville'>

# %%
df_clean.groupby('ville').sum()['Chiffre affaire'].sort_values(ascending=False).plot.barh(figsize=(10, 8))
# Out:
# /tmp/ipykernel_5934/2962888477.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_clean.groupby('ville').sum()['Chiffre affaire'].sort_values(ascending=False).plot.barh(figsize=(10, 8))
# <AxesSubplot: ylabel='ville'>

# %%
# Mauvaise analyse car les y sont différent x2 CA et x1 Qte

x1 = df_clean.groupby('ville')['Quantity Ordered'].sum()
x2 = df_clean.groupby('ville')['Chiffre affaire'].sum()

kwargs = dict(alpha=0.5, bins=20)

plt.hist(x1, **kwargs, color='blue', label='Extinct')
plt.hist(x2, **kwargs, color='orange', label='Critically Endangered')

plt.title("Rapport entre qte de produits vendu et chiffre d'affaire")
# Out:
# Text(0.5, 1.0, "Rapport entre qte de produits vendu et chiffre d'affaire")

# %% [markdown]
# #### À quelle heure devons nous passer de la publicité pour augmenter nos ventes

# %% [markdown]
# À quelle heure on vend le plus

# %%
df_clean['heure'] = df_clean.index.hour
df_clean['time'] = df_clean.index.time
df_clean.sample(5)
# Out:
#                      Order ID                   Product  Quantity Ordered  \
# Order Date
# 2019-07-17 17:30:00    231336        Macbook Pro Laptop                 1
# 2019-02-05 02:11:00    158906  Lightning Charging Cable                 1
# 2019-12-10 12:15:00    301288          Wired Headphones                 1
# 2019-04-18 19:06:00    191454      USB-C Charging Cable                 1
# 2019-03-24 22:44:00    174760  Lightning Charging Cable                 1
#
#                      Price Each                          Purchase Address  \
# Order Date
# 2019-07-17 17:30:00     1700.00      777 Lake St, San Francisco, CA 94016
# 2019-02-05 02:11:00       14.95  110 Washington St, Los Angeles, CA 90001
# 2019-12-10 12:15:00       11.99    685 Spruce St, San Francisco, CA 94016
# 2019-04-18 19:06:00       11.95      986 13th St, San Francisco, CA 94016
# 2019-03-24 22:44:00       14.95   272 Johnson St, San Francisco, CA 94016
#
# ...

# %%
df_clean.groupby('heure').sum()['Chiffre affaire'].sort_values(ascending=False)
# Out:
# /tmp/ipykernel_5934/1778104036.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_clean.groupby('heure').sum()['Chiffre affaire'].sort_values(ascending=False)
# heure
# 19    2370005.59
# 12    2269676.91
# 11    2267169.73
# 20    2242856.37
# 18    2176209.65
# 13    2118394.83
# 17    2086082.23
# 14    2045085.42
# 21    2013288.02
# 10    1907179.29
# 15    1900151.56
# 16    1864530.92
# 9     1612498.90
# 22    1578173.21
# 8     1181363.76
# 23    1161803.96
# 7      734595.75
# 0      698694.76
# 1      447663.86
# 6      441523.14
# 2      234191.08
# 5      224313.72
# 4      161350.57
# 3      142976.54
# Name: Chiffre affaire, dtype: float64

# %%
ca_par_heure = pd.DataFrame(df_clean.groupby('heure').sum()['Chiffre affaire'])
ca_par_heure
# Out:
# /tmp/ipykernel_5934/554620047.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ca_par_heure = pd.DataFrame(df_clean.groupby('heure').sum()['Chiffre affaire'])
#        Chiffre affaire
# heure
# 0            698694.76
# 1            447663.86
# 2            234191.08
# 3            142976.54
# 4            161350.57
# 5            224313.72
# 6            441523.14
# 7            734595.75
# 8           1181363.76
# 9           1612498.90
# 10          1907179.29
# 11          2267169.73
# 12          2269676.91
# 13          2118394.83
# 14          2045085.42
# 15          1900151.56
# 16          1864530.92
# 17          2086082.23
# 18          2176209.65
# 19          2370005.59
# 20          2242856.37
# 21          2013288.02
# 22          1578173.21
# 23          1161803.96

# %%
sns.lineplot(data=ca_par_heure['Chiffre affaire'])
plt.xticks(ticks=range(0, 24))
plt.grid()
plt.show()

# %% [markdown]
# On devrait afficher les publicités entre 10 et 11 et entre 18 et 19

# %% [markdown]
# #### Les produits souvent achetés ensemble

# %% [markdown]
# Les produits vendus ensemble ont le même Order ID

# %%
df_clean['Order ID'].duplicated()  # Retourne les lignes qui ont un true
# Le précédent ne prend pas en compte les premiers éléments, il prend juste en compte les duplicated, c'est à dire True
# Pour éviter cela on met keep=False
df_m = df_clean[df_clean['Order ID'].duplicated(keep=False)].copy()
df_m
# Out:
#                      Order ID                     Product  Quantity Ordered  \
# Order Date
# 2019-01-01 07:29:00    144804                      iPhone                 1
# 2019-01-01 07:29:00    144804            Wired Headphones                 1
# 2019-01-01 11:25:00    148074        USB-C Charging Cable                 1
# 2019-01-01 11:25:00    148074                Google Phone                 1
# 2019-01-01 12:02:00    148450    Lightning Charging Cable                 1
# ...                       ...                         ...               ...
# 2020-01-01 00:10:00    311386                      iPhone                 1
# 2020-01-01 00:22:00    297817                      iPhone                 1
# 2020-01-01 00:22:00    297817    Lightning Charging Cable                 2
# 2020-01-01 05:13:00    300519  Bose SoundSport Headphones                 1
# 2020-01-01 05:13:00    300519    Lightning Charging Cable                 1
#
# ...

# %%
df_clean.shape
# Out:
# (182735, 10)

# %%
def concat_prod_par_order_id(p: list):
    return ";".join(p)

# %%
 df_m.groupby("Order ID")['Product'].apply(concat_prod_par_order_id)
# Out:
# Order ID
# 141275              USB-C Charging Cable;Wired Headphones
# 141290     AA Batteries (4-pack);Apple Airpods Headphones
# 141365                   Wired Headphones;Vareebadd Phone
# 141384                  USB-C Charging Cable;Google Phone
# 141450            Bose SoundSport Headphones;Google Phone
#                                ...
# 319536                Macbook Pro Laptop;Wired Headphones
# 319556                      Google Phone;Wired Headphones
# 319584                            iPhone;Wired Headphones
# 319596                    iPhone;Lightning Charging Cable
# 319631    34in Ultrawide Monitor;Lightning Charging Cable
# Name: Product, Length: 6928, dtype: object

# %%
ensemb = df_m.groupby("Order ID")['Product'].apply(concat_prod_par_order_id)

# %%
from itertools import combinations
from collections import Counter

count = Counter()

# %%
# Combinations fait toutes les combinaisons(ici 2 à 2) de couple unique possibles d'une liste
# list(combinations(['a', 'c', 'b'], 2))
# Ensuite Counter les compte (compter le nombre d'occurence de couple)
Counter(combinations(['a', 'c', 'b'], 2))
# Out:
# Counter({('a', 'c'): 1, ('a', 'b'): 1, ('c', 'b'): 1})

# %%
ensemb.to_list()
# Out:
# ['USB-C Charging Cable;Wired Headphones',
#  'AA Batteries (4-pack);Apple Airpods Headphones',
#  'Wired Headphones;Vareebadd Phone',
#  'USB-C Charging Cable;Google Phone',
#  'Bose SoundSport Headphones;Google Phone',
#  'iPhone;Apple Airpods Headphones',
#  'Google Phone;Apple Airpods Headphones',
#  'iPhone;Wired Headphones;Apple Airpods Headphones',
#  'Apple Airpods Headphones;USB-C Charging Cable',
#  'Lightning Charging Cable;Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  'Bose SoundSport Headphones;27in FHD Monitor',
#  'Google Phone;USB-C Charging Cable',
#  'Wired Headphones;iPhone',
#  'USB-C Charging Cable;Google Phone',
#  'AAA Batteries (4-pack);AA Batteries (4-pack)',
#  'USB-C Charging Cable;Wired Headphones;Vareebadd Phone',
#  'USB-C Charging Cable;Google Phone',
#  'Wired Headphones;Vareebadd Phone',
#  'Lightning Charging Cable;34in Ultrawide Monitor',
#  'Wired Headphones;USB-C Charging Cable',
# ...

# %%
for achat in ensemb.to_list():
    products = achat.split(';')
    
    print(products)
    count.update(Counter(combinations(products, 2)))
#     break
# Out:
# ['USB-C Charging Cable', 'Wired Headphones']
# ['AA Batteries (4-pack)', 'Apple Airpods Headphones']
# ['Wired Headphones', 'Vareebadd Phone']
# ['USB-C Charging Cable', 'Google Phone']
# ['Bose SoundSport Headphones', 'Google Phone']
# ['iPhone', 'Apple Airpods Headphones']
# ['Google Phone', 'Apple Airpods Headphones']
# ['iPhone', 'Wired Headphones', 'Apple Airpods Headphones']
# ['Apple Airpods Headphones', 'USB-C Charging Cable']
# ['Lightning Charging Cable', 'Wired Headphones']
# ['iPhone', 'Lightning Charging Cable']
# ['Bose SoundSport Headphones', '27in FHD Monitor']
# ['Google Phone', 'USB-C Charging Cable']
# ['Wired Headphones', 'iPhone']
# ['USB-C Charging Cable', 'Google Phone']
# ['AAA Batteries (4-pack)', 'AA Batteries (4-pack)']
# ['USB-C Charging Cable', 'Wired Headphones', 'Vareebadd Phone']
# ['USB-C Charging Cable', 'Google Phone']
# ['Wired Headphones', 'Vareebadd Phone']
# ['Lightning Charging Cable', '34in Ultrawide Monitor']
# ...

# %%
count
# Out:
# Counter({('USB-C Charging Cable', 'Wired Headphones'): 103,
#          ('AA Batteries (4-pack)', 'Apple Airpods Headphones'): 38,
#          ('Wired Headphones', 'Vareebadd Phone'): 78,
#          ('USB-C Charging Cable', 'Google Phone'): 487,
#          ('Bose SoundSport Headphones', 'Google Phone'): 121,
#          ('iPhone', 'Apple Airpods Headphones'): 176,
#          ('Google Phone', 'Apple Airpods Headphones'): 11,
#          ('iPhone', 'Wired Headphones'): 247,
#          ('Wired Headphones', 'Apple Airpods Headphones'): 54,
#          ('Apple Airpods Headphones', 'USB-C Charging Cable'): 37,
#          ('Lightning Charging Cable', 'Wired Headphones'): 71,
#          ('iPhone', 'Lightning Charging Cable'): 465,
#          ('Bose SoundSport Headphones', '27in FHD Monitor'): 14,
#          ('Google Phone', 'USB-C Charging Cable'): 479,
#          ('Wired Headphones', 'iPhone'): 205,
#          ('AAA Batteries (4-pack)', 'AA Batteries (4-pack)'): 39,
# ...

# %%
count.most_common(10)
# Out:
# [(('Lightning Charging Cable', 'iPhone'), 518),
#  (('USB-C Charging Cable', 'Google Phone'), 487),
#  (('Google Phone', 'USB-C Charging Cable'), 479),
#  (('iPhone', 'Lightning Charging Cable'), 465),
#  (('iPhone', 'Wired Headphones'), 247),
#  (('Google Phone', 'Wired Headphones'), 221),
#  (('Wired Headphones', 'iPhone'), 205),
#  (('USB-C Charging Cable', 'Vareebadd Phone'), 193),
#  (('Wired Headphones', 'Google Phone'), 189),
#  (('Apple Airpods Headphones', 'iPhone'), 179)]

# %% [markdown]
# #### Produit le plus vendu

# %%
df_clean
# Out:
#                      Order ID                     Product  Quantity Ordered  \
# Order Date
# 2019-01-01 03:07:00    147268            Wired Headphones                 1
# 2019-01-01 03:40:00    148041        USB-C Charging Cable                 1
# 2019-01-01 04:56:00    149343    Apple Airpods Headphones                 1
# 2019-01-01 05:53:00    149964      AAA Batteries (4-pack)                 1
# 2019-01-01 06:03:00    149350        USB-C Charging Cable                 2
# ...                       ...                         ...               ...
# 2020-01-01 04:13:00    304165      AAA Batteries (4-pack)                 1
# 2020-01-01 04:21:00    299125        USB-C Charging Cable                 1
# 2020-01-01 04:54:00    305840  Bose SoundSport Headphones                 1
# 2020-01-01 05:13:00    300519  Bose SoundSport Headphones                 1
# 2020-01-01 05:13:00    300519    Lightning Charging Cable                 1
#
# ...

# %%
df_clean.groupby('Product')['Quantity Ordered'].sum().sort_values(ascending=False)
# Out:
# Product
# AAA Batteries (4-pack)        30487
# AA Batteries (4-pack)         27148
# USB-C Charging Cable          23555
# Lightning Charging Cable      22841
# Wired Headphones              20201
# Apple Airpods Headphones      15383
# Bose SoundSport Headphones    13236
# 27in FHD Monitor               7429
# iPhone                         6732
# 27in 4K Gaming Monitor         6134
# 34in Ultrawide Monitor         6076
# Google Phone                   5440
# Flatscreen TV                  4724
# Macbook Pro Laptop             4645
# 20in Monitor                   4058
# ThinkPad Laptop                4054
# Vareebadd Phone                2023
# LG Washing Machine              649
# LG Dryer                        640
# Name: Quantity Ordered, dtype: int64
